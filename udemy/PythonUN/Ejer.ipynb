# %%
Nombre = "Juan"
Edad = 30
pais = "España"
frase = "Buenos dias"

print(f'Hola, mi nombre es {Nombre}, tengo {Edad} años y soy de {pais}. {frase}!')
# Out:
# Hola, mi nombre es Juan, tengo 30 años y soy de España. Buenos dias!
